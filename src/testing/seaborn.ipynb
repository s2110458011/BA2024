# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
pd.set_option("mode.copy_on_write", True)

# %%
survey = pd.read_csv('data/survey.csv')

# %%
#!ln -s /Users/theresagschweidl/Documents/GitHub/BA2024/src/backend/data_processor/cleaner.py cleaner.py
# Out:
# ln: cleaner.py: File exists

# %%
import cleaner as cl
data = cl.extract_columns_by_name(survey, ['Zeitstempel', 'Geschlecht'])
data = cl.set_index_column_by_name(data, 'Zeitstempel')
data = cl.drop_time_component(data, 'index')
data
# Out:
#            Geschlecht
# 2021-03-18   Weiblich
# 2021-03-18   Weiblich
# 2021-03-18   Männlich
# 2021-03-18   Weiblich
# 2021-03-22   Männlich
# ...               ...
# 2021-04-25   Weiblich
# 2021-04-26   Männlich
# 2021-04-29   Weiblich
# 2021-06-01   Weiblich
# 2021-06-05   Männlich
#
# [918 rows x 1 columns]

# %%
timeline_data = survey[['Zeitstempel', 'Geschlecht']]
timeline_data['Zeitstempel'] = pd.to_datetime(timeline_data['Zeitstempel'], dayfirst=True)
#timeline_data.loc[:, 'Zeitstempel']= pd.to_datetime(timeline_data['Zeitstempel'], dayfirst=True)
timeline_data.loc[:, 'Zeitstempel']= timeline_data['Zeitstempel'].dt.date
timeline_data
# Out:
#     Zeitstempel Geschlecht
# 0    2021-03-18   Weiblich
# 1    2021-03-18   Weiblich
# 2    2021-03-18   Männlich
# 3    2021-03-18   Weiblich
# 4    2021-03-22   Männlich
# ..          ...        ...
# 913  2021-04-25   Weiblich
# 914  2021-04-26   Männlich
# 915  2021-04-29   Weiblich
# 916  2021-06-01   Weiblich
# 917  2021-06-05   Männlich
#
# [918 rows x 2 columns]

# %%
pivot_df = timeline_data.pivot_table(index='Zeitstempel', columns='Geschlecht', aggfunc=len, fill_value=0)
pivot_df['Total'] = pivot_df['Männlich'] + pivot_df['Sonstiges'] + pivot_df['Weiblich']
pivot_df
# Out:
# Geschlecht   Männlich  Sonstiges  Weiblich  Total
# Zeitstempel
# 2021-03-18          1          0         3      4
# 2021-03-22          4          0         0      4
# 2021-03-23         11          1         7     19
# 2021-03-24          1          0         1      2
# 2021-03-25          1          0         0      1
# 2021-03-26        110          1       145    256
# 2021-03-27         12          1        35     48
# 2021-03-28          7          0         6     13
# 2021-03-29          3          0         4      7
# 2021-03-30         15          0        24     39
# 2021-03-31          2          0         6      8
# 2021-04-01          4          0         0      4
# 2021-04-02          1          0         3      4
# 2021-04-03          0          0         2      2
# 2021-04-07        177          3       165    345
# 2021-04-08         33          0        42     75
# 2021-04-09         14          0        12     26
# ...

# %%
sns.lineplot(pivot_df, x='Zeitstempel', y='Total')
plt.xticks(rotation=45, ha='right')
# Out:
# (array([18701., 18718., 18732., 18748., 18762., 18779.]),
#  [Text(18701.0, 0, '2021-03-15'),
#   Text(18718.0, 0, '2021-04-01'),
#   Text(18732.0, 0, '2021-04-15'),
#   Text(18748.0, 0, '2021-05-01'),
#   Text(18762.0, 0, '2021-05-15'),
#   Text(18779.0, 0, '2021-06-01')])

# %%
survey.columns
# Out:
# Index(['Zeitstempel', 'Geschlecht', 'Alter',
#        'Höchste abgeschlossene Ausbildung',
#        'Studieren Sie derzeit oder haben Sie in der Vergangenheit studiert?',
#        'Arbeiten Sie während Ihres Studiums oder haben Sie während ihres Studiums gearbeitet? Wenn ja,wie viele Stunden pro Woche?',
#        'Wie empfinden Sie ihre Work-Life-Balance bezüglich Studium + Arbeit bzw. haben Sie empfunden?',
#        'Hat/Hatte Ihre Arbeit während des Studiums direkt etwas mit Ihrem Studium zu tun?',
#        'Ist Ihre Arbeit neben dem Studium aus einem verpflichtendem Praktikum entstanden?',
#        'Bitte schätzen Sie Ihr ideologisches Weltbild ein.',
#        'Bitte schätzen Sie Ihre Wertevorstellung ein.',
#        'Sind Sie politisch interessiert?',
#        'Bitte geben Sie das Land an, in dem Sie wählen dürfen.',
#        'Sehen Sie Ihre politischen Anliegen in der aktuellen Regierung Ihres Landes (in dem Sie wählen dürfen) vertreten?',
# ...

# %%
question_1 = 'Alter'
question_2 = 'Wie wollen Sie lieber wohnen?'
ages = survey[question_1]
house = survey[question_2]
survey = survey.sort_values(by=['Alter'])

# %%
sns.catplot(survey, x=survey['Höchste abgeschlossene Ausbildung'],  y=survey[question_1], hue=survey['Geschlecht'], kind='point', order=['Pflichtschule', 'Lehre', 'Weiterführende Schule ohne Matura',
            'Matura', 'Bachelorstudium', 'Masterstudium', 'Doktoratsstudium', 'Sonstiges'])
plt.xticks(rotation=55, ha='right')
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'Pflichtschule'),
#   Text(1, 0, 'Lehre'),
#   Text(2, 0, 'Weiterführende Schule ohne Matura'),
#   Text(3, 0, 'Matura'),
#   Text(4, 0, 'Bachelorstudium'),
#   Text(5, 0, 'Masterstudium'),
#   Text(6, 0, 'Doktoratsstudium'),
#   Text(7, 0, 'Sonstiges')])

# %%
def plot_2_categories_scatterplot(x, y, df: pd.DataFrame) -> None:
    scale = 500*df['count'].size
    size = df['count']/df['count'].sum()*scale
    self.ax.scatter(x, y, size, data=df, zorder=2)
    
    return None

def compute_counts_of_observation(raw_data: pd.DataFrame, cat1: str, cat2: str) -> pd.DataFrame:
    df_counts = raw_data.groupby([cat1, cat2]).size().reset_index()
    df_counts.columns.values[df_counts.columns==0] = 'count'
    return df_counts

# %%
df = survey[['Alter', 'Geschlecht']]
x = 'Alter'
y = 'Geschlecht'
df_counts = df.groupby([x, y]).size().reset_index()
df_counts.columns.values[df_counts.columns == 0] = 'count'

df_counts
# Out:
#     Alter Geschlecht  count
# 0   10-19   Männlich     14
# 1   10-19  Sonstiges      1
# 2   10-19   Weiblich     30
# 3   20-29   Männlich    302
# 4   20-29  Sonstiges      3
# 5   20-29   Weiblich    348
# 6   30-39   Männlich     81
# 7   30-39  Sonstiges      1
# 8   30-39   Weiblich     70
# 9   40-49   Männlich      9
# 10  40-49   Weiblich     29
# 11  50-59   Männlich      7
# 12  50-59   Weiblich     12
# 13  60-69   Männlich      3
# 14  60-69   Weiblich      6
# 15   < 10   Männlich      1
# 16  >= 70  Sonstiges      1

# %%
# Compute a size variable for the markers so that they have a good size regardless
# of the total count and the number of unique values in each categorical variable
scale = 50*df_counts['count'].size
size = df_counts['count']/df_counts['count'].sum()*scale
col_n = len(df[x].unique())

# Create matplotlib scatter plot with additional formatting
fig, ax = plt.subplots(figsize=(8,6))
scatter = ax.scatter(y, x, size, data=df_counts, zorder=2) #, color='#2A788E'
#handles, labels = scatter.legend_elements(prop="sizes", alpha=0.6)
for i, row in df_counts.iterrows():
    ax.annotate(row[x],
                    (row[x], row[y]), 
                    textcoords="offset points", 
                    xytext=(5,5), 
                    ha='center')
kw = dict(prop="sizes", color=scatter.cmap(0.4), fmt="{x}",
          func=lambda s: s/50)
#legend2 = ax.legend(*scatter.legend_elements(**kw), bbox_to_anchor=(0.5, -0.27), loc="lower center", title="Sizes", labelspacing=2, ncols=col_n)
#ax.grid(color='grey', linestyle='--', alpha=0.4, zorder=1)
ax.tick_params(length=0)
#ax.set_frame_on(False)
#ax.margins(.1)

# %%
sns.countplot(df, y='Alter', hue='Geschlecht')
# Out:
# <Axes: xlabel='count', ylabel='Alter'>
